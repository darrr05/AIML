# %%
import numpy as np

path = "./dataset/numbers_ex.csv"
data = np.genfromtxt(path, dtype= float, skip_header=1, names=None, delimiter=",", encoding=None)

print("shape of data : " , data.shape)
print("datatype of data : " , data.dtype)
print(data[:,1])
print(data[:,3])

cost = data[:,3]/data[:,1]98+8

print()

new_data = np.insert(data, 4,values=cost,axis = 1)
print(new_data)
# Out:
# shape of data :  (4, 4)
# datatype of data :  float64
# [ 70.  60.  50. 120.]
# [ 910.5  1000.25  890.5   800.  ]
#
# [[1.00000000e+00 7.00000000e+01 8.00000000e+00 9.10500000e+02
#   1.30071429e+01]
#  [2.00000000e+00 6.00000000e+01 1.30000000e+01 1.00025000e+03
#   1.66708333e+01]
#  [3.00000000e+00 5.00000000e+01 1.80000000e+01 8.90500000e+02
#   1.78100000e+01]
#  [4.00000000e+00 1.20000000e+02 2.30000000e+01 8.00000000e+02
#   6.66666667e+00]]
